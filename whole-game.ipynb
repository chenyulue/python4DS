# %% [markdown]
# (whole-game)=
#
# # 全流程纵览
#
# 本书此部分的宗旨是快速概述数据科学的核心工具链——如数据导入、清洗、转换与可视化（如下图所示），使您能够纵览数据科学的"完整流程"。我们旨在提纲挈领地呈现各核心模块，帮助读者构建处理真实（即便相对简单）数据集的能力。后续章节将深入探讨每个环节，逐步扩展您应对数据科学挑战的能力边界。

# %%
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats("svg")

# %%
# remove-input
import graphviz

dot = graphviz.Digraph(comment="Data science workflow")
dot.attr(compound="true")
dot.edge("导入", "清洗")

with dot.subgraph(name="cluster_0") as c:
    c.attr(style="filled", color="lightgrey")
    c.node_attr.update(style="filled", color="white")
    c.edges(
        [("可视化", "分析"), ("分析", "转换"), ("转换", "可视化")]
    )
    c.attr(label="理解")

dot.edge("清洗", "分析", lhead="cluster_0")

dot.edge("分析", "交流", ltail="cluster_0")

dot

# %% [markdown]
# 本章结束后，我们将深入探讨数据科学的四大核心工具模块：
#
# - **可视化分析**（{ref}`data-visualise`）是Python编程的理想切入点，其技术价值直观显著：您将能够创建优雅且信息丰富的图表，以帮助你理解数据。本节将系统讲解绘图基础架构及数据可视化进阶技术。
# - **数据转换**（{ref}`data-transform`）作为可视化补充，深入讲解关键数据的处理方法：变量筛选、观测值过滤、新变量构建及统计量计算。
# - **数据整理**（{ref}`data-tidy`）聚焦数据清洗与"整洁数据"范式。该范式通过统一表格数据结构，显著提升转换、可视化及建模的效率。本节将详解其底层原理与实现路径。
# - **数据导入**（{ref}`data-import`）作为预处理前置环节，系统讲解.csv文件加载至Python会话的核心方法。
#
# 穿插其间的其他四个章节聚焦于Python工作流程：
#
# - **基础实践**（{ref}`workflow-basics`）、**代码风格**（{ref}`workflow-style`）与**编码规范**（{ref}`workflow-writing-code`）三章，系统构建代码编写与组织的最佳实践体系。
# - **环境与包管理**（{ref}`workflow-packages-and-environments`）深入解析软件包管理机制与项目环境隔离策略。
#
# 最终，**技术支持**（{ref}`workflow-help`）章节提供高效获取技术帮助与持续学习的方法论指导。
